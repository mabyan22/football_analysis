# %%
import numpy as np
import matplotlib as mt
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataframe=pd.read_csv("../Data/playerstats.csv",sep=',', header=1)

# %%
selectedData = dataframe.filter(['Player','90s', 'npxG+xA'], axis=1)

# %%
selectedData = selectedData[selectedData['90s'] > 7]
selectedData = selectedData[selectedData['npxG+xA'] > 4]
len(selectedData)
# Out:
# 44

# %%
for i, row in selectedData.iterrows():
    ifor_val=selectedData.at[i,'Player'].split("\\",1)
    selectedData.at[i,'Player']=ifor_val[0]
    
    #selectedData.at[i,'Player'] = ifor_val
selectedData
# Out:
#                  Player   90s  npxG+xA
# 34        Marco Asensio  10.0      5.1
# 35           Iago Aspas  16.8      8.3
# 62        Karim Benzema  18.3     14.4
# 63       Álex Berenguer  12.2      4.1
# 67           Lucas Boyé  12.8      4.6
# 83       Sergio Canales  16.6      6.3
# 90     Yannick Carrasco  16.5      5.2
# 111        Ángel Correa  12.9      6.5
# 127       Memphis Depay  15.3      8.2
# 128        Sergiño Dest  10.7      4.2
# 129         Boulaye Dia   9.7      5.7
# 145        Adri Embarba  16.5      4.2
# 159         Nabil Fekir  16.6      7.1
# 171     Jorge de Frutos  13.3      6.0
# 175       Álvaro García  16.6      6.4
# 182         Raúl García  11.6      4.8
# 189          Maxi Gómez  12.4      4.2
# 205   Arnaut Groeneveld   8.8      6.2
# 209      Gonçalo Guedes  17.1      6.3
# 234      Alexander Isak  13.0      5.1
# 241  Luis Javier Suárez  18.0      6.9
# 249        Willian José  11.4      5.3
# 250              Joselu  18.5      5.8
# 255              Juanmi  11.7      7.0
# 257     Vinicius Júnior  17.8     11.1
# 261                Kike  14.7      5.6
# 277        Thomas Lemar  10.6      4.9
# 290   José Luis Morales  16.2      6.7
# 331          Santi Mina  16.2      6.7
# 333            Rafa Mir  13.2      5.1
# 339        Jorge Molina  11.3      4.1
# 346      Alberto Moreno   8.9      4.3
# 348       Gerard Moreno   9.5      8.0
# 354        Iker Muniain  17.3      8.0
# 382     Mikel Oyarzabal  12.0      6.8
# 388       Daniel Parejo  14.6      4.6
# 406         Yeremi Pino  11.6      5.2
# 433          Luis Rioja  18.5      4.1
# 486         Luis Suárez  12.5      5.8
# 496       Raúl de Tomás  18.6      7.5
# 502         Óscar Trejo  12.8      4.1
# 503      Manu Trigueros  13.1      4.8
# 507           Enes Ünal  15.0      4.4
# 533      Iñaki Williams  18.4     10.7

# %%
selectedData.plot(kind='scatter',x='npxG+xA',y='90s',color='red')
plt.show()
