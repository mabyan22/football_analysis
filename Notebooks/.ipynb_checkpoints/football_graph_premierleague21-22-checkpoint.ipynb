# %%
import numpy as np
import matplotlib as mt
import matplotlib.pyplot as plt
import pandas as pd
# ref = https://fbref.com/en/comps/9/2021-2022/stats/2021-2022-Premier-League-Stats

# %%
dataframe = pd.read_csv('../Data/player_stats_pl.csv',sep=',',header=1,encoding = 'unicode_escape')
dataframe
# Out:
#       Rk                Player   Nation   Pos            Squad  Age  Born  MP  \
# 0      1            Max Aarons  eng ENG    DF     Norwich City   21  2000  34
# 1      2             Che Adams  sct SCO    FW      Southampton   25  1996  30
# 2      3       Rayan At Nouri   fr FRA    DF           Wolves   20  2001  23
# 3      4       Kristoffer Ajer   no NOR    DF        Brentford   23  1998  24
# 4      5            Nathan Ak   nl NED    DF  Manchester City   26  1995  14
# ..   ...                   ...      ...   ...              ...  ...   ...  ..
# 541  542         Wilfried Zaha   ci CIV    FW   Crystal Palace   28  1992  33
# 542  543  Christoph Zimmermann   de GER    DF     Norwich City   28  1993   3
# 543  544   Oleksandr Zinchenko   ua UKR    DF  Manchester City   24  1996  15
# 544  545          Hakim Ziyech   ma MAR  FWMF          Chelsea   28  1993  23
# 545  546            Kurt Zouma   fr FRA    DF         West Ham   26  1994  24
#
#      Starts   Min  ...  npxG   xA  npxG+xA  xG.1  xA.1  xG+xA  npxG.1  \
# 0        32  2881  ...   0.7  1.4      2.1  0.02  0.04   0.07    0.02
# 1        23  2039  ...   7.1  2.6      9.7  0.31  0.12   0.43    0.31
# 2        20  1828  ...   0.7  1.3      2.1  0.04  0.07   0.10    0.04
# 3        23  1995  ...   0.8  1.4      2.2  0.04  0.06   0.10    0.04
# 4        10   923  ...   1.1  0.5      1.6  0.11  0.05   0.16    0.11
# ..      ...   ...  ...   ...  ...      ...   ...   ...    ...     ...
# 541      31  2760  ...   4.0  4.8      8.8  0.31  0.16   0.46    0.13
# 542       2   157  ...   0.1  0.0      0.1  0.04  0.00   0.04    0.04
# 543      10  1047  ...   0.4  2.0      2.5  0.04  0.18   0.21    0.04
# 544      14  1319  ...   3.4  3.5      6.9  0.23  0.24   0.47    0.23
# 545      24  2078  ...   0.9  0.0      0.9  0.04  0.00   0.04    0.04
#
#      npxG+xA.1  Matches  Unnamed: 33
# 0         0.07  Matches          NaN
# 1         0.43  Matches          NaN
# 2         0.10  Matches          NaN
# 3         0.10  Matches          NaN
# 4         0.16  Matches          NaN
# ..         ...      ...          ...
# 541       0.29  Matches          NaN
# 542       0.04  Matches          NaN
# 543       0.21  Matches          NaN
# 544       0.47  Matches          NaN
# 545       0.04  Matches          NaN
#
# [546 rows x 34 columns]

# %%
#cleaning the data
for i, row in dataframe.iterrows():
    dataframe.at[i,'Age']=str(dataframe.at[i,'Age'])
    ifor_val=dataframe.at[i,'Age'].split("-",1)
    dataframe.at[i,'Age']=ifor_val[0]
    dataframe.at[i,'Age']=float(dataframe.at[i,'Age'])
for i, row in dataframe.iterrows():
    ifor_val=dataframe.at[i,'Player'].split("\\",1)
    dataframe.at[i,'Player']=ifor_val[0]

# %%
selectedData = dataframe.filter(['Player','Age','90s', 'xG','xA'], axis=1)
selectedData
# Out:
#                    Player   Age   90s   xG   xA
# 0              Max Aarons  21.0  32.0  0.7  1.4
# 1               Che Adams  25.0  22.7  7.1  2.6
# 2         Rayan At Nouri  20.0  20.3  0.7  1.3
# 3         Kristoffer Ajer  23.0  22.2  0.8  1.4
# 4              Nathan Ak  26.0  10.3  1.1  0.5
# ..                    ...   ...   ...  ...  ...
# 541         Wilfried Zaha  28.0  30.7  9.4  4.8
# 542  Christoph Zimmermann  28.0   1.7  0.1  0.0
# 543   Oleksandr Zinchenko  24.0  11.6  0.4  2.0
# 544          Hakim Ziyech  28.0  14.7  3.4  3.5
# 545            Kurt Zouma  26.0  23.1  0.9  0.0
#
# [546 rows x 5 columns]

# %%
selectedData = selectedData[selectedData['xA'] > 2.4]
selectedData = selectedData[selectedData['xG'] > 2.4]
selectedData = selectedData[selectedData['Age']< 26]
selectedData
len(selectedData.index)
# Out:
# 36

# %%
selectedData.plot(kind='scatter',x='xG',y='xA',color='blue')
plt.title('xG against xA for U25 players in the Premier League')



for a, row in selectedData.iterrows():
    afor_val=selectedData.at[a,'Player'].split(" ",1)
    try:
        selectedData.at[a,'Player']=afor_val[1]
    except:
        selectedData.at[a,'Player']=afor_val[0]

    
for index, row in selectedData.iterrows():
    if row['xG']>8 or row['xA']>7:
        plt.text(row['xG'],row['xA'],row['Player'])
plt.show()
